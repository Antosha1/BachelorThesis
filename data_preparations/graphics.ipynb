# %%
import matplotlib.pyplot as plt

# %%
train_losses = [15.737, 11.533, 8.514, 6.601, 4.320, 3.881, 2.395, 1.992, 1.649, 1.703, 1.432, 1.289, 1.703, 1.332, 1.289]
valid_losses = [12.033, 9.830, 8.013, 6.950, 6.693, 5.536, 5.101, 5.264, 5.395, 5.410, 5.332, 5.045, 5.194, 5.132, 5.145]
test_losses = [13.758, 11.817, 11.171, 9.438, 8.617, 8.127, 7.696, 7.377, 7.422, 7.126, 6.823, 6.732, 6.987, 6.923, 7.032]

# %%
len(test_losses)
# Out:
# 15

# %%
    plt.figure(figsize=[10, 7])
    plt.plot(range(1,16),train_losses, label='train')
    plt.plot(range(1,16),valid_losses, label='valid')
    plt.plot(range(1,16),test_losses, label='test')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend()
    plt.show()

# %%
f_scores = [76.12, 80.16, 82.87, 82.41, 82.68, 82.53, 82.44, 83.34, 82.51, 82.76, 82.28, 83.69, 83.41, 82.76, 82.39]
precisions = [76.74, 81.66, 80.79, 80.89, 83.08, 81.61, 81.20, 83.06, 80.07, 83.70, 82.14, 82.65]
recalls = [71.67, 76.24, 80.95, 82.29, 82.29, 84.09, 84.54, 85.07, 85.62, 83.76, 84.61, 84.54]

# %%
plt.figure(figsize=[10, 7])
plt.plot(range(1, 16), f_scores, label='F-score', color='red')
plt.xlabel('epoch')
plt.ylabel('F-score')
plt.legend(loc='best')
plt.show()
