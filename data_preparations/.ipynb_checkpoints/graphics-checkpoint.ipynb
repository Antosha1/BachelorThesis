# %%
import matplotlib.pyplot as plt

# %%
train_losses = [20.737, 17.533, 12.514, 8.601, 8.320, 5.881, 5.395, 4.492, 5.649, 5.103, 5.432, 5.289]
valid_losses = [16.033, 11.830, 11.013, 10.950, 10.693, 10.536, 10.701, 10.164, 10.895, 10.910, 10.932, 10.845, 10.894]
test_losses = [17.358, 14.817, 14.171, 13.738, 13.117, 12.927, 12.596, 12.377, 12.422, 12.926, 13.123, 13.032, 12.987]

# %%
    plt.figure(figsize=[10, 7])
    plt.plot(train_losses, label='train')
    plt.plot(valid_losses, label='valid')
    plt.plot(test_losses, label='test')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
